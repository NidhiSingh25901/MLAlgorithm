# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiSingh25901/MLAlgorithm/blob/main/CV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/sample_data/Flower.jpg')
print(img.shape)
newimg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(newimg.shape)
# Out:
# (4032, 3024, 3)
# (4032, 3024, 3)

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(newimg)
plt.axis("off")
plt.show()
