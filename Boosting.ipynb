# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiSingh25901/MLAlgorithm/blob/main/Boosting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# Load dataset
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Base learner
base_model = DecisionTreeClassifier(max_depth=1)

# AdaBoost ensemble
boost_model = AdaBoostClassifier(
    estimator=base_model,
    n_estimators=50,      # Number of weak learners
    learning_rate=1.0,
    random_state=42
)

boost_model.fit(X_train, y_train)
y_pred = boost_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

# Plotting the first feature of X_test against y_pred
plt.scatter(X_test[:, 0], y_pred)
plt.xlabel("First feature of X_test")
plt.ylabel("Predicted class")
plt.title("Scatter plot of first feature vs predicted class")
plt.show()
# Out:
# Accuracy: 1.0
